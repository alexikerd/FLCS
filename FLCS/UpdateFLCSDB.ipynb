# %%
import numpy as np
import pandas as pd
from os import path
from sqlalchemy import *

FLCS_Path = path.abspath(path.curdir)

rawdata = pd.read_csv(FLCS_Path + r"\FLCS.csv", delimiter=',',names = ("Split","Player","Position","Team","Win/Loss","Points"),usecols=(0,1,3,4,5,6))
rawdata['Week'] = ''
rawdata['Opponent'] = rawdata['Team'].astype(str).str[-3:]
rawdata['Excess'] = rawdata['Position']
rawdata['Win/Loss'] = rawdata['Win/Loss'].astype(str).str[0]
rawdata['Team'] = rawdata['Team'].astype(str).str[:3]
rawdata = rawdata[["Split","Week","Player","Position","Team","Opponent","Win/Loss","Points","Excess"]]
rawdata['Week'] = rawdata['Player'].astype(str).str[-1:]
rawdata['Position'] = rawdata['Position'].fillna(method='ffill')
a = 1
week = []
replace = []
while (a < 10):
    week.append("Week %d" % a)
    replace.append(np.nan)
    a = a + 1
rawdata['Player'] = rawdata['Player'].replace(week,replace)
rawdata['Player'] = rawdata['Player'].fillna(method='ffill')
rawdata = rawdata[rawdata['Excess'].isna()]
rawdata = rawdata.drop(columns = ['Excess'])

    

rawdata
# Out:
#        Split Week        Player  Position Team Opponent Win/Loss  Points
# 1          1    1    Doublelift  AD Carry  CLG      DIG        W   28.57
# 2          1    1    Doublelift  AD Carry  CLG      TIP        W   46.03
# 3          1    2    Doublelift  AD Carry  CLG       T8        W   26.42
# 4          1    2    Doublelift  AD Carry  CLG      TSM        L   12.63
# 5          1    3    Doublelift  AD Carry  CLG       GV        W   40.20
# 6          1    3    Doublelift  AD Carry  CLG      NME        W   35.66
# 7          1    4    Doublelift  AD Carry  CLG      TDK        W   26.83
# 8          1    4    Doublelift  AD Carry  CLG       C9        W   50.38
# 9          1    5    Doublelift  AD Carry  CLG       TL        L   15.88
# 10         1    5    Doublelift  AD Carry  CLG      TSM        L   14.79
# 11         1    6    Doublelift  AD Carry  CLG       GV        L    6.30
# 12         1    6    Doublelift  AD Carry  CLG      TIP        L   23.31
# 13         1    7    Doublelift  AD Carry  CLG      NME        W   22.15
# 14         1    7    Doublelift  AD Carry  CLG      TDK        W   38.05
# 15         1    8    Doublelift  AD Carry  CLG       TL        W   11.15
# 16         1    8    Doublelift  AD Carry  CLG       C9        W   41.05
# 17         1    9    Doublelift  AD Carry  CLG      DIG        W   30.62
# 18         1    9    Doublelift  AD Carry  CLG       T8        W   35.38
# 20         1    1        Apollo  AD Carry  TIP       T8        W   35.79
# 21         1    1        Apollo  AD Carry  TIP      CLG        L   23.29
# 22         1    2        Apollo  AD Carry  TIP      TSM        L   15.69
# 23         1    2        Apollo  AD Carry  TIP       C9        W   23.39
# 24         1    3        Apollo  AD Carry  TIP      TDK        W   20.52
# 25         1    3        Apollo  AD Carry  TIP       TL        L   16.12
# 26         1    4        Apollo  AD Carry  TIP      DIG        L   12.42
# 27         1    4        Apollo  AD Carry  TIP      NME        W   33.95
# 28         1    5        Apollo  AD Carry  TIP       GV        L   35.30
# 29         1    5        Apollo  AD Carry  TIP       C9        W   33.84
# 30         1    6        Apollo  AD Carry  TIP      NME        W   14.24
# 31         1    6        Apollo  AD Carry  TIP      CLG        W   19.54
# ...      ...  ...           ...       ...  ...      ...      ...     ...
# 12715      7    9       Wiggily   Jungler  CLG      GGS        W   19.07
# 12717      7    1         Keith  AD Carry  C9        CG        L   10.66
# 12718      7    1         Keith  AD Carry  C9       OPT        W   12.22
# 12719      7    2         Keith  AD Carry  C9       GGS        L    8.08
# 12720      7    2         Keith  AD Carry  C9       100        L    8.08
# 12721      7    3         Keith  AD Carry  C9       TSM        L    0.00
# 12722      7    3         Keith  AD Carry  C9       FOX        L    0.00
# 12724      7    1        Adrian   Support  FOX      FLY        W   22.72
# 12725      7    1        Adrian   Support  FOX       CG        W    8.69
# 12726      7    3        Adrian   Support  FOX       TL        L    0.00
# 12727      7    3        Adrian   Support  FOX       C9        W    0.00
# 12729      7    1          Kwon   Support  FLY      FOX        L    8.73
# 12730      7    1          Kwon   Support  FLY      TSM        L    3.88
# 12731      7    2          Kwon   Support  FLY      100        L    4.11
# 12732      7    2          Kwon   Support  FLY      OPT        W   14.38
# 12733      7    3          Kwon   Support  FLY      GGS        W    0.00
# 12734      7    3          Kwon   Support  FLY      CLG        W    0.00
# 12736      7    6        Piglet  AD Carry  CG       100        L   19.28
# 12737      7    6        Piglet  AD Carry  CG        TL        L    2.26
# 12739      7    6          Moon   Jungler  CG       100        L   16.50
# 12740      7    6          Moon   Jungler  CG        TL        L    4.69
# 12742      7    9        bobqin       Mid  GGS      FLY        L    6.13
# 12743      7    9        bobqin       Mid  GGS      CLG        L   10.87
# 12745      7    6        Vulcan   Support  CG       100        L   12.88
# 12746      7    6        Vulcan   Support  CG        TL        L    2.42
# 12748      7    9  Fallenbandit       Top  CLG       CG        W   15.13
# 12750      7    8         Jesiz   Support  MSF      H2K        W    8.01
# 12751      7    8         Jesiz   Support  MSF       G2        L    1.84
# 12753      7    3          Gate   Support  OPT      CLG        L    5.12
# 12754      7    3          Gate   Support  OPT      100        L   -0.86
#
# [11918 rows x 8 columns]
